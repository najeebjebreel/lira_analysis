# %%
# Figure 1 in the paper. 
# A notebook to plot the LiRA (online) thresholds at two FPRs: (a) For 1 single run and (b) pooled across 12 seeds.



import matplotlib
matplotlib.use("Agg")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from plot_style import configure_popets_style
import seaborn as sns

BASE_FONTSIZE = 12
configure_popets_style(base_fontsize=BASE_FONTSIZE, family="serif")
sns.set_theme(context="paper", style="whitegrid")

# ------------------ Okabe–Ito palette (colorblind-safe) ------------------
OI_BLUE    = "#0072B2"
OI_ORANGE  = "#E69F00"
OI_GREEN   = "#009E73"
OI_PURPLE  = "#CC79A7"
OI_VERMIL  = "#D55E00"
OI_GREY    = "#888888"


# ------------------ Data loading & filtering ------------------
def _load_thresholds_filtered(
    csv_path,
    attack: str,
    target_fpr: float,
    prior_equals: float = 0.01,
    mode_equals: str = "target",
):
    """
    Keep only rows where:
      - mode == "target"
      - attack == <attack> (exact string match, case-insensitive)
      - target_fpr == {1e-5 or 1e-3}
      - prior == 0.01
    Returns a 1D array of finite thresholds for that CSV.
    """
    df = pd.read_csv(csv_path)

    # Coerce numerics
    df["target_fpr"] = pd.to_numeric(df.get("target_fpr"), errors="coerce")
    df["prior"]      = pd.to_numeric(df.get("prior"),      errors="coerce")

    # Robust string equality
    def _eq_str(series, target):
        return series.astype(str).str.strip().str.casefold() == str(target).strip().casefold()

    m_mode   = _eq_str(df["mode"],   mode_equals)
    m_attack = _eq_str(df["attack"], attack)
    m_tfpr   = np.isclose(df["target_fpr"].to_numpy(), float(target_fpr), rtol=1e-6, atol=1e-12)
    m_prior  = np.isclose(df["prior"].to_numpy(),      float(prior_equals), rtol=1e-6, atol=1e-12)

    vals = pd.to_numeric(df.loc[m_mode & m_attack & m_tfpr & m_prior, "threshold"], errors="coerce").to_numpy()
    vals = vals[np.isfinite(vals)]
    return vals

def _load_pooled_for_variant(csv_paths, attack, target_fpr, prior=0.01):
    """Concatenate thresholds across the 9 seed runs for a given (attack, target_fpr)."""
    chunks = []
    for p in csv_paths:
        v = _load_thresholds_filtered(p, attack=attack, target_fpr=target_fpr, prior_equals=prior)
        if v.size:
            chunks.append(v)
    return np.concatenate(chunks) if chunks else np.array([])

# ------------------ Robust dispersion (median-centric) ------------------
def _median_rmad(vals):
    med = float(np.median(vals))
    mad = float(np.median(np.abs(vals - med)))
    rmad = 100.0 * 1.4826 * mad / med if med != 0 else np.nan
    return med, rmad

# ------------------ Main: four pooled boxes (9 seeds; 2 FPRs) ------------------
def plot_online_thresholds_pooled_seeds(
    pooled_csvs,        # list[str]  ← the 9 per-seed CSVs
    out_path,           # str        ← PDF path
    whisker_mode="tukey",  # "tukey" (1.5*IQR) or "p05p95"
    show_fliers=False,
):
    """
    Builds two boxes (pooled across the 9 seeds) for:
      - LiRA (online) @ 1e-5
      - LiRA (online) @ 1e-3
    Filters also enforce mode=="target" and prior==0.01.
    """
    attack = "LiRA (online)"
    fprs = [1e-5, 1e-3]

    variants = [
        (attack, fprs[0], r"Online, $10^{-5}$"),
        (attack, fprs[1], r"Online, $10^{-3}$"),
    ]
    colors = [OI_BLUE, OI_ORANGE]
    fills  = [c + "33" for c in colors]  # light alpha fill

    # Load pooled thresholds
    datasets = []
    for atk, tfpr, _ in variants:
        vals = _load_pooled_for_variant(pooled_csvs, attack=atk, target_fpr=tfpr, prior=0.01)
        if vals.size == 0:
            raise ValueError(f"No thresholds after filtering for: attack='{atk}', target_fpr={tfpr}")
        datasets.append(vals)

    whis = (5, 95) if whisker_mode == "p05p95" else 1.5

    fig, ax = plt.subplots(figsize=(3.0, 2.3))  # Reduced from 3.6
    plt.subplots_adjust(left=0.14, right=0.995, top=0.95, bottom=0.26)

    positions = [0.7, 1.05]  # Shifted closer together

    bp = ax.boxplot(
        datasets,
        positions=positions,
        vert=True, patch_artist=True, widths=0.2,
        whis=whis, showfliers=show_fliers
    )

    # Color styling (keep as is)
    for patch, fc, ec in zip(bp['boxes'], fills, colors):
        patch.set_facecolor(fc)
        patch.set_edgecolor(ec)
        patch.set_linewidth(1.0)
    for med in bp['medians']:
        med.set_color(OI_VERMIL); med.set_linewidth(1.2)
    for i, line in enumerate(bp["whiskers"]):
        box_idx = i // 2
        line.set_color(colors[box_idx]); line.set_linewidth(0.9)
    for i, line in enumerate(bp["caps"]):
        box_idx = i // 2
        line.set_color(colors[box_idx]); line.set_linewidth(0.9)

    # Labels - centered below each box
    ax.set_xticks(positions)
    ax.set_xticklabels([lab for _, _, lab in variants], fontsize=8.5)
    ax.set_xlim(0.5, 1.25)  # Tighter limits aligned with right box
    # ax.set_ylabel(r"Threshold $\tau$")

    # Q3-aligned annotations with adjusted positioning
    for pos_idx, (xpos, vals) in enumerate(zip(positions, datasets)):
        med, rmad = _median_rmad(vals)
        q3 = float(np.percentile(vals, 75))
        
        # Different positioning for each box
        if pos_idx == 0:  # First box (10^-5)
            offset_x, offset_y = 8, 5
        else:  # Second box (10^-3) - shifted left
            offset_x, offset_y = 25, 8
        
        ax.annotate(
            f"Median = {med:.2f}\nrMAD = {rmad:.1f}%",
            xy=(xpos, q3),
            xytext=(offset_x, offset_y), textcoords="offset points",
            ha="left" if pos_idx == 0 else "right", va="bottom",
            fontsize=6.5, color="#1A2732",
            bbox=dict(facecolor="white", edgecolor="none", alpha=0.65, pad=0.4),
            clip_on=False
        )

    out_path = Path(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)
    plt.tight_layout()
    fig.savefig(out_path, bbox_inches="tight", transparent=True)
    plt.close(fig)
    return str(out_path)

# %%
# ------------------ Example usage (12 identical seeds) ------------------
pooled_paths_12seeds = [
    "analysis_results/cifar10/resnet18/seed1/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed2/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed3/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed4/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed5/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed6/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed7/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed8/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed9/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed10/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed11/per_model_metrics_two_modes.csv",
    "analysis_results/cifar10/resnet18/seed12/per_model_metrics_two_modes.csv",
]


plot_online_thresholds_pooled_seeds(
    pooled_csvs=[pooled_paths_12seeds[3]],
    out_path="figures/thresh_boxplot_single.pdf",
    whisker_mode="tukey",
    show_fliers=False,
)

plot_online_thresholds_pooled_seeds(
    pooled_csvs=pooled_paths_12seeds,
    out_path="figures/thresh_boxplot_multi.pdf",
    whisker_mode="tukey",
    show_fliers=False,
)
