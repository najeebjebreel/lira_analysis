# %%
# A notebook for generating reproduciblity analysis plots (Figure 2, 3, 5, 6, 9, 10 in the paper)

import os
import shutil
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from itertools import combinations
from matplotlib.ticker import MaxNLocator, PercentFormatter

# Import functions from the analysis utilities module
from analysis_utils import (
    to_id_set,
    compute_scenario,
    aggregate_over_configs,
    compute_dynamic_ylims,
    _nice_bounds_numeric,  # Add this here
    SAMPLE_ID_COL
)

from plot_style import configure_popets_style

# %%
# ============================= YOU FILL THESE ================================
"""
Each directory is expected to include per-sample vulnerability CSVs produced by
*online LiRA (shadow-based)* at the two nominal FPRs we analyze (1e-5 ≡ 0.001%,
1e-3 ≡ 0.1%). Filenames are expected to be:

  samples_vulnerability_ranked_online_shadow_{TAG}.csv

where TAG is:
  - "0p001pct" for 1e-5 (0.001%)
  - "0p1pct"   for 1e-3 (0.1%)

The twelve "seed*" entries are the *Identical* scenario (same config, different seeds).
We also evaluate +1-different scenarios (MixUp drp=0.15, BS=512 drp=0.2, TL, Arch),
and aggregate over +2, +3, +4 different by averaging across all combinations
of those 4 variants.

The INPUTS below are generated in the analysis_results folder from post_analysis scripts.
Make sure they are generated before running this script.
"""

INPUTS = {
    # Identical setting, 12 seeds {1..12}  ← set to your actual run folders
    "seed1":  "analysis_results/cifar10/resnet18/seed1",
    "seed2":  "analysis_results/cifar10/resnet18/seed2",
    "seed3":  "analysis_results/cifar10/resnet18/seed3",
    "seed4":  "analysis_results/cifar10/resnet18/seed4",
    "seed5":  "analysis_results/cifar10/resnet18/seed5",
    "seed6":  "analysis_results/cifar10/resnet18/seed6",
    "seed7":  "analysis_results/cifar10/resnet18/seed7",
    "seed8":  "analysis_results/cifar10/resnet18/seed8",
    "seed9":  "analysis_results/cifar10/resnet18/seed9",
    "seed10": "analysis_results/cifar10/resnet18/seed10",
    "seed11": "analysis_results/cifar10/resnet18/seed11",
    "seed12": "analysis_results/cifar10/resnet18/seed12",

    # +1 different variants  ← update paths if yours differ
    # MixUp (drp=0.15)
    "mixup_drp0.15": "analysis_results/cifar10/resnet18/mixup_drp0.15",

    # BS=512 (drp=0.2)
    "bs512_drp0.2": "analysis_results/cifar10/resnet18/bs512_drp0.2",

    # Transfer Learning
    "transfer": "analysis_results/cifar10/resnet18/tl",

    # Architecture change (example WRN-28-2 path)
    "arch": "analysis_results/cifar10/wrn28-2/seed42",
}

# ---------------------------- Outputs ---------------------------------------
OUT_FIG_DIR = "figures"
OUT_TAB_DIR = "tables"
os.makedirs(OUT_FIG_DIR, exist_ok=True)
os.makedirs(OUT_TAB_DIR, exist_ok=True)

# Analyze these two nominal FPRs
FPRS = [1e-5, 1e-3]

def fpr_to_tag(f):
    """Map 1e-5 -> '0p001pct', 1e-3 -> '0p1pct' (generalized formatter)."""
    pct = f * 100.0  # in %
    # format with up to 3 decimals, strip trailing zeros
    s = f"{pct:.3f}".rstrip('0').rstrip('.')
    return s.replace('.', 'p') + "pct"



# Base typography
BASE_FONTSIZE = 12

configure_popets_style(base_fontsize=BASE_FONTSIZE, family="serif")
sns.set_theme(context="paper", style="whitegrid")

# %%
# ============================= Docstring / Header ============================
"""
Code to generate reproducibility analysis figures: Figure 2 and 5.
For each FPR, aggregates across combinations of runs to compute:

  • Avg. Jaccard = |∩| / |∪|  (agreement / reproducibility)
  • Avg. intersection = |∩|  (size of common core / stability)
  • Avg. union = |∪|        (coverage / breadth)

Figure mapping for reproducibility (per FPR):
  - jaccard_noleg_{TAG}.pdf   → Fig. a-style (Avg. Jaccard vs k)
  - intersection_{TAG}.pdf    → Fig. b-style (Avg. intersection vs k)
  - union_{TAG}.pdf           → Fig. c-style (Avg. union vs k)
  - legend_{TAG}.pdf          → shared legend strip

Tables (per FPR):
  tables/reproducibility_12seeds_plus4_{TAG}.csv  # exact numbers used

Scenarios & labels:
  - "Identical (2–12 seeds)"                # 12 same-config runs; vary seeds only
  - "+1 different (MixUp, DRP=0.15)"        # baseline seeds + MixUp variant
  - "+1 different (BS=512, DRP=0.2)"        # baseline seeds + BS512 variant
  - "+1 different (Arch)"                   # baseline seeds + architecture change
  - "+1 different (TL)"                     # baseline seeds + transfer learning
  - "+2 different"                          # average across all pairs of the 4 variants
  - "+3 different"                          # average across all triplets of the 4 variants
  - "+4 different"                          # average across all 4 variants together
"""

# Line width; no markers (lines only), tuned for compact panels.
LW = 2.5

def draw_lines(ax, df, ykey, ylabel, pct, DYNAMIC_YLIMS,
               ORDER, COL, STYLE, show_values_legend=False, show_xlabel=True):
    """Draw a multi-scenario line plot vs k for a given metric key."""
    for scen in ORDER:
        sub = df[df["scenario"] == scen].sort_values("k")
        if sub.empty:
            continue
        ax.plot(
            sub["k"], sub[ykey],
            color=COL[scen],
            linestyle=STYLE[scen],
            lw=LW,
            label=scen,
        )

    # X-axis labeling and ticks
    if show_xlabel:
        ax.set_xlabel(r"$k$")
        ax.tick_params(axis="x", which="both",
                       direction="out", length=3, width=0.6,
                       labelbottom=True)
    else:
        ax.set_xlabel("")
        ax.set_xticks([])  # remove tick positions
        ax.tick_params(axis="x", which="both",
                       bottom=False, top=False,
                       labelbottom=False)

    # Y-axis label / limits / ticks
    ax.set_ylabel(ylabel)
    ax.set_ylim(*DYNAMIC_YLIMS[ykey])
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.tick_params(axis="y", which="both",
                   direction="out", length=3, width=0.6)

    # Subtle grid suitable for print
    ax.grid(True, linestyle=":", linewidth=0.6, alpha=0.45)
    ax.minorticks_on()
    ax.grid(which="minor", axis="y", linestyle=":", linewidth=0.4, alpha=0.2)

    # Percent formatting for Jaccard panels
    if pct:
        ax.set_yticks(np.arange(0.0, DYNAMIC_YLIMS[ykey][1]+0.01, 0.1))
        ax.yaxis.set_major_formatter(PercentFormatter(1.0))
        ax.axhline(0.10, color="grey", lw=0.8, ls=":", alpha=0.45)
        ax.axhline(0.05, color="grey", lw=0.8, ls=":", alpha=0.45)

    # Compact in-panel legend with final values (lines only)
    if show_values_legend:
        from matplotlib.lines import Line2D

        legend_elements = []
        for scen in ORDER:
            sub = df[df["scenario"] == scen].sort_values("k")
            if sub.empty:
                continue
            y_end = sub[ykey].iloc[-1]
            final_val = f"{y_end*100:.1f}%" if pct else f"{y_end:.0f}"

            line = Line2D(
                [0], [0],
                color=COL[scen],
                linestyle=STYLE[scen],
                linewidth=LW * 0.9,
                label=final_val,
            )
            legend_elements.append(line)

        ax.legend(
            handles=legend_elements,
            loc="best",
            fontsize=BASE_FONTSIZE - 1,
            frameon=True,
            framealpha=0.95,
            edgecolor="gray",
            ncol=2,
            handlelength=1.3,
            handletextpad=0.35,
            columnspacing=0.8,
            borderpad=0.35,
            labelspacing=0.25,
            title="Final values",
            title_fontsize=BASE_FONTSIZE - 1,
        )

def save_panel(path_pdf, all_results, ykey, ylabel, pct,
               DYNAMIC_YLIMS, ORDER, COL, STYLE, show_xlabel):
    """Save a single metric-vs-k panel with compact values legend inside."""
    fig, ax = plt.subplots(figsize=(4.6, 3.2))
    draw_lines(
        ax, all_results, ykey, ylabel, pct,
        DYNAMIC_YLIMS, ORDER, COL, STYLE,
        show_values_legend=True, show_xlabel=show_xlabel,
    )
    fig.tight_layout()
    fig.savefig(path_pdf, bbox_inches="tight", dpi=400)
    plt.close(fig)

def save_legend(path_pdf, all_results, DYNAMIC_YLIMS, ORDER, COL, STYLE):
    """Save a standalone legend strip (scenario names only, no values)."""
    fig_tmp, ax_tmp = plt.subplots()
    draw_lines(
        ax_tmp, all_results, "avg_jaccard", "Avg. Jaccard", True,
        DYNAMIC_YLIMS, ORDER, COL, STYLE,
        show_values_legend=False, show_xlabel=False,
    )
    handles, labels = ax_tmp.get_legend_handles_labels()
    plt.close(fig_tmp)

    # Slightly wider legend strip for better spacing under a 2-column figure.
    fig_leg = plt.figure(figsize=(5, 0.55))
    fig_leg.legend(
        handles, labels,
        loc="center",
        ncol=4,
        frameon=True,
        fontsize=BASE_FONTSIZE - 0.5,
        columnspacing=1.0,
        handletextpad=0.6,
        borderpad=0.6,
    )
    fig_leg.savefig(path_pdf, bbox_inches="tight", pad_inches=0.02, dpi=400)
    plt.close(fig_leg)

palette = sns.color_palette("colorblind", 10)

# ============================= PROCESS PER FPR ===============================
for fpr in FPRS:
    TAG = fpr_to_tag(fpr)  # "0p001pct" or "0p1pct"
    CSV_BASENAME = f"samples_vulnerability_ranked_online_shadow_{TAG}.csv"

    # ----------- Load named sets (for this FPR) -----------
    BASE_TOKENS = [f"seed{i}" for i in range(1, 13)]
    for t in BASE_TOKENS:
        if t not in INPUTS:
            raise KeyError(f"Missing INPUTS['{t}']")

    sets_baseline = [
        (t, to_id_set(INPUTS[t], csv_basename=CSV_BASENAME, id_col=SAMPLE_ID_COL))
        for t in BASE_TOKENS
    ]
    M_BASE = len(sets_baseline)  # should be 12

    # Variants (exactly four; used to build +1, +2, +3, +4 scenarios)
    for v in ["mixup_drp0.15", "bs512_drp0.2", "arch", "transfer"]:
        if v not in INPUTS:
            raise KeyError(f"Missing INPUTS['{v}']")

    V_MIXUP = ("MixUp_drp0.15", to_id_set(
        INPUTS["mixup_drp0.15"], csv_basename=CSV_BASENAME, id_col=SAMPLE_ID_COL))
    V_BS512 = ("BS512_drp0.2", to_id_set(
        INPUTS["bs512_drp0.2"], csv_basename=CSV_BASENAME, id_col=SAMPLE_ID_COL))
    V_ARCH = ("Arch", to_id_set(
        INPUTS["arch"], csv_basename=CSV_BASENAME, id_col=SAMPLE_ID_COL))
    V_TL = ("TL", to_id_set(
        INPUTS["transfer"], csv_basename=CSV_BASENAME, id_col=SAMPLE_ID_COL))
    VARIANTS = [V_MIXUP, V_BS512, V_ARCH, V_TL]

    # ----------------------------- Scenarios -------------------------------
    scen_identical = compute_scenario(
        f"Identical (2–{M_BASE} seeds)",
        sets_baseline, kmin=2, kmax=M_BASE,
    )
    scen_mixup = compute_scenario(
        "+1 different (MixUp, DRP=0.15)", sets_baseline + [V_MIXUP],
    )
    scen_bs512 = compute_scenario(
        "+1 different (BS=512, DRP=0.2)", sets_baseline + [V_BS512],
    )
    scen_arch = compute_scenario(
        "+1 different (Arch)", sets_baseline + [V_ARCH],
    )
    scen_tl = compute_scenario(
        "+1 different (TL)", sets_baseline + [V_TL],
    )

    def _configs_for_m(m: int):
        return [sets_baseline + list(combo) for combo in combinations(VARIANTS, m)]

    scen_plus2 = aggregate_over_configs("+2 different", _configs_for_m(2))
    scen_plus3 = aggregate_over_configs("+3 different", _configs_for_m(3))
    scen_plus4 = aggregate_over_configs("+4 different", _configs_for_m(4))

    all_results = pd.concat(
        [
            scen_identical,
            scen_mixup, scen_bs512, scen_arch, scen_tl,
            scen_plus2, scen_plus3, scen_plus4,
        ],
        ignore_index=True,
    )

    # Save table with exact numbers (tagged per FPR)
    tab_path = os.path.join(
        OUT_TAB_DIR, f"reproducibility_12seeds_plus4_{TAG}.csv")
    all_results.to_csv(tab_path, index=False, float_format="%.4f")

    # Dynamic y-limits keep axes tight yet readable.
    DYNAMIC_YLIMS = compute_dynamic_ylims(all_results)

    # ---------------------------- Styling (per FPR) ------------------------
    COL = {
        f"Identical (2–{M_BASE} seeds)": "#0072B2",  # blue
        "+1 different (MixUp, DRP=0.15)": "#D55E00",  # orange-red
        "+1 different (BS=512, DRP=0.2)": "#118A69",  # green
        "+1 different (Arch)": "#7A2655",             # magenta
        "+1 different (TL)": "#7E771F",               # yellow-olive
        "+2 different": "#000000",                    # black
        "+3 different": "#B11515",                    # red
        "+4 different": "#999999",                    # light gray
    }

    STYLE = {
        f"Identical (2–{M_BASE} seeds)": "solid",
        "+1 different (MixUp, DRP=0.15)": (0, (5, 2)),
        "+1 different (BS=512, DRP=0.2)": (0, (3, 1)),
        "+1 different (Arch)": (0, (1, 1)),
        "+1 different (TL)": (0, (3, 1, 1, 1)),
        "+2 different": (0, (5, 1, 1, 1)),
        "+3 different": (0, (7, 2, 1, 2)),
        "+4 different": (0, (1, 2)),
    }

    ORDER_ALL = [
        f"Identical (2–{M_BASE} seeds)",
        "+1 different (MixUp, DRP=0.15)",
        "+1 different (BS=512, DRP=0.2)",
        "+1 different (Arch)",
        "+1 different (TL)",
        "+2 different",
        "+3 different",
        "+4 different",
    ]
    ORDER = [k for k in ORDER_ALL if (all_results["scenario"] == k).any()]

    # ---------- export panels (PDF, tagged per FPR) ----------
    fig_j = os.path.join(OUT_FIG_DIR, f"jaccard_noleg_{TAG}.pdf")
    fig_i = os.path.join(OUT_FIG_DIR, f"intersection_{TAG}.pdf")
    fig_u = os.path.join(OUT_FIG_DIR, f"union_{TAG}.pdf")
    fig_l = os.path.join(OUT_FIG_DIR, f"legend_{TAG}.pdf")

    # Only the bottom row (higher FPR) gets x-axis labels / ticks.
    show_xlabel = True
    # show_xlabel = (fpr == 1e-3)
    save_panel(
        fig_j, all_results, "avg_jaccard", "Avg. Jaccard",
        True, DYNAMIC_YLIMS, ORDER, COL, STYLE, show_xlabel,
    )
    save_panel(
        fig_i, all_results, "avg_intersection", "Avg. intersection",
        False, DYNAMIC_YLIMS, ORDER, COL, STYLE, show_xlabel,
    )
    save_panel(
        fig_u, all_results, "avg_union", "Avg. union",
        False, DYNAMIC_YLIMS, ORDER, COL, STYLE, show_xlabel,
    )
    save_legend(fig_l, all_results, DYNAMIC_YLIMS, ORDER, COL, STYLE)

    print(f"\n✓ [{TAG}] Generated 4 figures:")
    print(f"  {fig_j}")
    print(f"  {fig_i}")
    print(f"  {fig_u}")
    print(f"  {fig_l}")
    print(f"✓ [{TAG}] Table: {tab_path}")

print("\n" + "=" * 80)
print("Reproducibility analysis complete for both FPRs!")
print("=" * 80)

# %%
# ============================= Docstring / Header ============================
"""
Code to generate reproducibility analysis figures: Figure 9 and 10.

Sweeps within-run support thresholds TP≥x for BOTH target FPRs.

The x-axis in the heatmaps corresponds to TP≥x; rows are k ∈ {2..M_BASE} (here M_BASE=12).

Exports (per FPR):
  figures/
    tpgeq_x_identical_heatmaps_{TAG}.pdf
  tables/
    tpgeq_x_identical_{TAG}_12seeds.csv
"""

# ============================= TP>=x — compact heatmaps (Identical only) =============================
# Thresholds to report
TP_THRESHOLDS = [1, 2, 3, 4, 5, 10, 20, 64]

def compute_identical_over_thresholds(tp_values, csv_basename):
    """
    Return long DF over thresholds for the Identical (2–M_BASE seeds) case only.

    For each threshold x in TP_THRESHOLDS:
      1) Rebuild each baseline set with TP≥x (stronger within-run support).
      2) Recompute metrics over k=2..M_BASE using the same combination logic.
      3) Append to a long-form DataFrame with 'tp_threshold' attached.
    """
    # Build 12 identical-seed runs for this FPR/tag
    BASE_TOKENS = [f"seed{i}" for i in range(1, 13)]
    for t in BASE_TOKENS:
        if t not in INPUTS:
            raise KeyError(f"Missing INPUTS['{t}']")

    # Preload baseline names (paths come from INPUTS)
    baseline_names = [(t, INPUTS[t]) for t in BASE_TOKENS]

    M_BASE = len(baseline_names)  # should be 12
    label_ident = f"Identical (2–{M_BASE} seeds)"

    rows = []
    for tpx in tp_values:
        # Rebuild baseline sets with tighter TP≥x
        sets_baseline_x = [
            (
                name,
                to_id_set(
                    path,
                    csv_basename=csv_basename,
                    id_col=SAMPLE_ID_COL,
                    tp_threshold=tpx,
                    fp_equals=None,   # keep all FPs (no forced FP=0 core)
                ),
            )
            for name, path in baseline_names
        ]
        # Compute across k = 2..M_BASE
        df = compute_scenario(label_ident, sets_baseline_x, kmin=2, kmax=M_BASE)
        df["tp_threshold"] = tpx
        rows.append(df)

    return pd.concat(rows, ignore_index=True)

def _fmt_percent(v):
    # One decimal place is a good compromise for PoPETs: compact but informative.
    return "" if pd.isna(v) else f"{v*100:.1f}"

def _fmt_int(v):
    return "" if pd.isna(v) else f"{int(round(v))}"

def _pivot(df, value):
    """Pivot helper producing k×(TP≥x) matrices for a chosen value column."""
    p = df.pivot(index="k", columns="tp_threshold", values=value).sort_index()
    return p.reindex(columns=TP_THRESHOLDS)

CMAP = "viridis"  # perceptually uniform, colorblind-friendly

# ============================= PROCESS PER FPR ===============================
for fpr in FPRS:
    TAG = fpr_to_tag(fpr)  # '0p001pct' or '0p1pct'
    CSV_BASENAME = f"samples_vulnerability_ranked_online_shadow_{TAG}.csv"

    # --- Build long-form table for this FPR ---
    ident_only = compute_identical_over_thresholds(TP_THRESHOLDS, csv_basename=CSV_BASENAME)

    # Save tidy table (tagged & 12seeds in name)
    out_tbl = os.path.join(OUT_TAB_DIR, f"tpgeq_x_identical_{TAG}_12seeds.csv")
    ident_only[["tp_threshold", "k", "avg_jaccard", "avg_intersection", "avg_union"]].to_csv(
        out_tbl, index=False, float_format="%.6f"
    )

    # --- Pivot to matrices for heatmaps ---
    p_j = _pivot(ident_only, "avg_jaccard")
    p_i = _pivot(ident_only, "avg_intersection")
    p_u = _pivot(ident_only, "avg_union")

    # Panel-specific limits (keep correct normalization)
    lims_j = (0, 1)
    lims_i = _nice_bounds_numeric(np.nanmin(p_i.values), np.nanmax(p_i.values))
    lims_u = _nice_bounds_numeric(np.nanmin(p_u.values), np.nanmax(p_u.values))

    # --- Plot three unified heatmaps (one row, three columns) ---
    fig, axes = plt.subplots(1, 3, figsize=(12, 4.0))   
    plt.subplots_adjust(
        wspace=0.08,
        left=0.07,
        right=0.99,
        top=0.86,
        bottom=0.26,
    )

    # A – Avg. Jaccard (percentage; compact, no colorbar)
    sns.heatmap(
        p_j,
        ax=axes[0],
        cmap=CMAP,
        vmin=lims_j[0],
        vmax=lims_j[1],
        annot=p_j.applymap(_fmt_percent),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=False,
        linewidths=0.4,
        linecolor="white",
    )
    axes[0].set_title("Avg. Jaccard (%)", fontsize=BASE_FONTSIZE)
    axes[0].set_xlabel("")  # x-label on middle panel only
    axes[0].set_ylabel("Runs combined ($k$)")
    axes[0].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # B – Avg. Intersection (integers; no colorbar)
    sns.heatmap(
        p_i,
        ax=axes[1],
        cmap=CMAP,
        vmin=lims_i[0],
        vmax=lims_i[1],
        annot=p_i.applymap(_fmt_int),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=False,
        linewidths=0.4,
        linecolor="white",
        yticklabels=False,  # Hide y-axis tick labels (only show on first panel)
    )
    axes[1].set_title("Avg. Intersection", fontsize=BASE_FONTSIZE)
    axes[1].set_xlabel("TP ≥ $x$")
    axes[1].set_ylabel("")
    axes[1].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # C – Avg. Union (integers) with a compact, unlabeled colorbar
    hm = sns.heatmap(
        p_u,
        ax=axes[2],
        cmap=CMAP,
        vmin=lims_u[0],
        vmax=lims_u[1],
        annot=p_u.applymap(_fmt_int),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=True,
        linewidths=0.4,
        linecolor="white",
        cbar_kws={"orientation": "vertical", "fraction": 0.05, "pad": 0.03},
        yticklabels=False,
    )
    axes[2].set_title("Avg. Union", fontsize=BASE_FONTSIZE)
    axes[2].set_xlabel("")
    axes[2].set_ylabel("")
    axes[2].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # Make the colorbar unlabeled and tickless (clean, non-dominant bar)
    cb = hm.collections[0].colorbar
    cb.set_label("")
    cb.set_ticks([])
    cb.outline.set_linewidth(0.5)

    # Set x-axis tick labels for all panels
    xticklabels = [str(t) for t in TP_THRESHOLDS]
    for ax in axes:
        ax.set_xticklabels(xticklabels, rotation=0)

    # Set y-axis tick labels only for the first panel (k values)
    axes[0].set_yticklabels(axes[0].get_yticklabels(), rotation=0)

    # Save tagged composite (per FPR)
    out_heatmap = os.path.join(OUT_FIG_DIR, f"tpgeq_x_identical_heatmaps_{TAG}.pdf")
    fig.savefig(out_heatmap, bbox_inches="tight", dpi=400)
    plt.close(fig)

    print(f"\n✓ [{TAG}] Heatmap figure:", out_heatmap)
    print(f"✓ [{TAG}] Table:", out_tbl)

print("\n" + "=" * 80)
print("Heatmap analysis complete for both FPRs!")
print("=" * 80)

# %%
# ============================= Docstring / Header ============================
"""
Code to generate reproducibility analysis figures: Figure 3 and 6.

Sweeps within-run support thresholds TP≥x@0FP for BOTH target FPRs.

The x-axis in the heatmaps corresponds to TP≥x@0FP; rows are k ∈ {2..M_BASE} (here M_BASE=12).

Exports (per FPR):
  figures/
    tpgeq_x_0fp_identical_heatmaps_{TAG}.pdf
  tables/
    tpgeq_x_0fp_identical_{TAG}_12seeds.csv
"""

# ============================= TP>=x — compact heatmaps (Identical only) =============================
# Thresholds to report
TP_THRESHOLDS = [1, 2, 3, 4, 5, 10, 20, 64]

def compute_identical_over_thresholds(tp_values, csv_basename):
    """
    Return long DF over thresholds for the Identical (2–M_BASE seeds) case only.

    For each threshold x in TP_THRESHOLDS:
      1) Rebuild each baseline set with TP≥x@0FP (stronger within-run support).
      2) Recompute metrics over k=2..M_BASE using the same combination logic.
      3) Append to a long-form DataFrame with 'tp_threshold' attached.
    """
    # Build 12 identical-seed runs for this FPR/tag
    BASE_TOKENS = [f"seed{i}" for i in range(1, 13)]
    for t in BASE_TOKENS:
        if t not in INPUTS:
            raise KeyError(f"Missing INPUTS['{t}']")

    # Preload baseline names (paths come from INPUTS)
    baseline_names = [(t, INPUTS[t]) for t in BASE_TOKENS]

    M_BASE = len(baseline_names)  # should be 12
    label_ident = f"Identical (2–{M_BASE} seeds)"

    rows = []
    for tpx in tp_values:
        # Rebuild baseline sets with tighter TP≥x
        sets_baseline_x = [
            (
                name,
                to_id_set(
                    path,
                    csv_basename=csv_basename,
                    id_col=SAMPLE_ID_COL,
                    tp_threshold=tpx,
                    fp_equals=0,   # FP=0 core
                ),
            )
            for name, path in baseline_names
        ]
        # Compute across k = 2..M_BASE
        df = compute_scenario(label_ident, sets_baseline_x, kmin=2, kmax=M_BASE)
        df["tp_threshold"] = tpx
        rows.append(df)

    return pd.concat(rows, ignore_index=True)

def _fmt_percent(v):
    # One decimal place is a good compromise for PoPETs: compact but informative.
    return "" if pd.isna(v) else f"{v*100:.1f}"

def _fmt_int(v):
    return "" if pd.isna(v) else f"{int(round(v))}"

def _pivot(df, value):
    """Pivot helper producing k×(TP≥x) matrices for a chosen value column."""
    p = df.pivot(index="k", columns="tp_threshold", values=value).sort_index()
    return p.reindex(columns=TP_THRESHOLDS)

CMAP = "viridis"  # perceptually uniform, colorblind-friendly

# ============================= PROCESS PER FPR ===============================
for fpr in FPRS:
    TAG = fpr_to_tag(fpr)  # '0p001pct' or '0p1pct'
    CSV_BASENAME = f"samples_vulnerability_ranked_online_shadow_{TAG}.csv"

    # --- Build long-form table for this FPR ---
    ident_only = compute_identical_over_thresholds(TP_THRESHOLDS, csv_basename=CSV_BASENAME)

    # Save tidy table (tagged & 12seeds in name)
    out_tbl = os.path.join(OUT_TAB_DIR, f"tpgeq_x_0fp_identical_{TAG}_12seeds.csv")
    ident_only[["tp_threshold", "k", "avg_jaccard", "avg_intersection", "avg_union"]].to_csv(
        out_tbl, index=False, float_format="%.6f"
    )

    # --- Pivot to matrices for heatmaps ---
    p_j = _pivot(ident_only, "avg_jaccard")
    p_i = _pivot(ident_only, "avg_intersection")
    p_u = _pivot(ident_only, "avg_union")

    # Panel-specific limits (keep correct normalization)
    lims_j = (0, 1)
    lims_i = _nice_bounds_numeric(np.nanmin(p_i.values), np.nanmax(p_i.values))
    lims_u = _nice_bounds_numeric(np.nanmin(p_u.values), np.nanmax(p_u.values))

    # --- Plot three unified heatmaps (one row, three columns) ---
    fig, axes = plt.subplots(1, 3, figsize=(12, 4.0)) 
    plt.subplots_adjust(
        wspace=0.08,
        left=0.07,
        right=0.99,
        top=0.86,
        bottom=0.26,
    )

    # A – Avg. Jaccard (percentage; compact, no colorbar)
    sns.heatmap(
        p_j,
        ax=axes[0],
        cmap=CMAP,
        vmin=lims_j[0],
        vmax=lims_j[1],
        annot=p_j.applymap(_fmt_percent),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=False,
        linewidths=0.4,
        linecolor="white",
    )
    axes[0].set_title("Avg. Jaccard (%)", fontsize=BASE_FONTSIZE)
    axes[0].set_xlabel("")  # x-label on middle panel only
    axes[0].set_ylabel("Runs combined ($k$)")
    axes[0].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # B – Avg. Intersection (integers; no colorbar)
    sns.heatmap(
        p_i,
        ax=axes[1],
        cmap=CMAP,
        vmin=lims_i[0],
        vmax=lims_i[1],
        annot=p_i.applymap(_fmt_int),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=False,
        linewidths=0.4,
        linecolor="white",
        yticklabels=False,  # Hide y-axis tick labels (only show on first panel)
    )
    axes[1].set_title("Avg. Intersection", fontsize=BASE_FONTSIZE)
    axes[1].set_xlabel("TP ≥ $x$ @0 FP")
    axes[1].set_ylabel("")
    axes[1].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # C – Avg. Union (integers) with a compact, unlabeled colorbar
    hm = sns.heatmap(
        p_u,
        ax=axes[2],
        cmap=CMAP,
        vmin=lims_u[0],
        vmax=lims_u[1],
        annot=p_u.applymap(_fmt_int),
        fmt="",
        annot_kws={"fontsize": BASE_FONTSIZE - 1},
        cbar=True,
        linewidths=0.4,
        linecolor="white",
        cbar_kws={"orientation": "vertical", "fraction": 0.05, "pad": 0.03},
        yticklabels=False,
    )
    axes[2].set_title("Avg. Union", fontsize=BASE_FONTSIZE)
    axes[2].set_xlabel("")
    axes[2].set_ylabel("")
    axes[2].tick_params(axis="both", labelsize=BASE_FONTSIZE - 1)

    # Make the colorbar unlabeled and tickless (clean, non-dominant bar)
    cb = hm.collections[0].colorbar
    cb.set_label("")
    cb.set_ticks([])
    cb.outline.set_linewidth(0.5)

    # Set x-axis tick labels for all panels
    xticklabels = [str(t) for t in TP_THRESHOLDS]
    for ax in axes:
        ax.set_xticklabels(xticklabels, rotation=0)

    # Set y-axis tick labels only for the first panel (k values)
    axes[0].set_yticklabels(axes[0].get_yticklabels(), rotation=0)

    # Save tagged composite (per FPR)
    out_heatmap = os.path.join(OUT_FIG_DIR, f"tpgeq_x_0fp_identical_heatmaps_{TAG}.pdf")
    fig.savefig(out_heatmap, bbox_inches="tight", dpi=400)
    plt.close(fig)

    print(f"\n✓ [{TAG}] Heatmap figure:", out_heatmap)
    print(f"✓ [{TAG}] Table:", out_tbl)

print("\n" + "=" * 80)
print("Heatmap analysis complete for both FPRs!")
print("=" * 80)
